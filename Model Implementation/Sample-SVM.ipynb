# %% [markdown]
# ## Importing in SVM related dependencies to use

# %%
import pandas as pd
import numpy as np

from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.preprocessing import MinMaxScaler
from sklearn.svm import SVC
from sklearn import metrics
from sklearn.datasets import load_breast_cancer

# %% [markdown]
# ## Storing dataset and examining the dataframe

# %%
cancer_dataset = load_breast_cancer()
df = pd.DataFrame(cancer_dataset['data'], columns=cancer_dataset['feature_names'])
df.head(10)
# Out:
#    mean radius  mean texture  mean perimeter  mean area  mean smoothness  \
# 0        17.99         10.38          122.80     1001.0          0.11840
# 1        20.57         17.77          132.90     1326.0          0.08474
# 2        19.69         21.25          130.00     1203.0          0.10960
# 3        11.42         20.38           77.58      386.1          0.14250
# 4        20.29         14.34          135.10     1297.0          0.10030
# 5        12.45         15.70           82.57      477.1          0.12780
# 6        18.25         19.98          119.60     1040.0          0.09463
# 7        13.71         20.83           90.20      577.9          0.11890
# 8        13.00         21.82           87.50      519.8          0.12730
# 9        12.46         24.04           83.97      475.9          0.11860
#
#    mean compactness  mean concavity  mean concave points  mean symmetry  \
# 0           0.27760         0.30010              0.14710         0.2419
# ...

# %% [markdown]
# ## Testing and Training our Model

# %%
(X_cancer, y_cancer) = load_breast_cancer(return_X_y=True, as_frame=True)
X_train, X_test, y_train, y_test = train_test_split(X_cancer, y_cancer, random_state= 0)
clf = SVC(kernel='linear').fit(X_train, y_train)

# %% [markdown]
# ## Predicting with the Classification variable created

# %%
y_pred = clf.predict(X_test)

# %%
# Print accuracy, precision and recall values
accruacy_score = metrics.accuracy_score(y_test, y_pred)
precision_score = metrics.precision_score(y_test, y_pred)
recall_score = metrics.recall_score(y_test, y_pred)

print("Accuracy Score:",accruacy_score)
print("Precision:",precision_score)
print("Recall:",recall_score)
# Out:
# Accuracy Score: 0.958041958041958
# Precision: 0.9883720930232558
# Recall: 0.9444444444444444
